# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("\'hello\'")
# Out:
# 'hello'

# %%
print('\"Hello World\"')
# Out:
# "Hello World"

# %%
print('\"!@#$%^&*()\"')
# Out:
# "!@#$%^&*()"

# %%
print('\"C:\\Download\\hello.cpp\"')
# Out:
# "C:\Download\hello.cpp"

# %%
a=15
print(a)
